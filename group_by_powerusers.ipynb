# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/Untitled/Desktop/grant_work/twitter-code/bayes/bug_testing_v2/by_hashtag/coal.csv', error_bad_lines=False, encoding='utf8', engine='python')

# %%
df.head()
# Out:
#             X          Y  OBJECTID  compound                     coord  \
# 0 -100.445801  39.783875      32.0    0.0772  39.7837304, -100.4458825
# 1  -94.611328  45.989685     111.0   -0.4199   45.9896587, -94.6113288
# 2 -118.242676  34.053711     257.0    0.4710  34.0536834, -118.2427669
# 3  -91.867004  47.903320     345.0   -0.4199   47.9032372, -91.8670873
# 4  -77.036499  38.895081     362.0    0.0000   38.8950092, -77.0365625
#
#       coord_X    coord_Y  created_at       geo_type            id  ...   \
# 0 -100.445882  39.783730  2017/11/22  User location  9.614440e+07  ...
# 1  -94.611329  45.989659  2017/11/22  User location  8.519690e+17  ...
# 2 -118.242767  34.053683  2017/11/22  User location  1.412834e+08  ...
# 3  -91.867087  47.903237  2017/11/22  User location  8.106096e+17  ...
# 4  -77.036563  38.895009  2017/11/22  User location  2.337119e+09  ...
#
#      neu    pos               primary_ge       screen_nam  \
# ...

# %%
df = df.groupby('screen_nam', as_index=False)['compound','x','y'].mean()

# %%
df
# Out:
#            screen_nam  compound           x          y
# 0             1029tak  0.000000  -77.727883  40.969989
# 1                10LY  0.369567  -77.036563  38.895009
# 2             10thDon  0.000000 -117.985904  35.125801
# 3     14_flippn_seats  0.000000 -118.755997  36.701463
# 4             1945rkn  0.077200 -100.445882  39.783730
# 5           1960weave  0.000000 -100.445882  39.783730
# 6        1979MELTDOWN  0.000000 -122.674195  45.520247
# 7              19ec55  0.077200 -102.410749  34.233137
# 8              1CaptD -0.308300 -118.289051  34.069750
# 9      1Earth1Sea1Sky -0.006133 -100.445882  39.783730
# 10         1Javierson  0.401900  -81.379039  28.542110
# 11       1LarryLittle  0.000000  -89.589101  40.693861
# 12    1Whistleblowers  0.765000 -118.755997  36.701463
# 13    2018MAGAMidTrmT  0.077200 -100.445882  39.783730
# 14           2qaz1wsx  0.051600  -71.058291  42.360253
# 15      305Resistance  0.670500 -100.445882  39.783730
# ...

# %%
filename = '/Volumes/Untitled/Desktop/grant_work/twitter-code/bayes/bug_testing_v2/by_hashtag/coal_powerusers.csv'
 
df.to_csv(filename, index=False, encoding='utf-8')
