# %%
import pandas as pd
import numpy as np

# %%
tweets = pd.read_csv('/Volumes/Untitled/Desktop/grant_work/twitter-code/bayes/bug_testing_v2/by_hashtag/coal.csv')

# %%
tweets
# Out:
#                X          Y  OBJECTID  compound  \
# 0    -100.445801  39.783875      32.0    0.0772
# 1     -94.611328  45.989685     111.0   -0.4199
# 2    -118.242676  34.053711     257.0    0.4710
# 3     -91.867004  47.903320     345.0   -0.4199
# 4     -77.036499  38.895081     362.0    0.0000
# 5    -120.737183  43.979309     373.0    0.5423
# 6    -121.955200  37.354126     391.0    0.0000
# 7     -92.479919  46.745911     393.0   -0.4199
# 8    -102.410706  34.233276     575.0    0.0000
# 9     -81.151611  41.101929     773.0    0.0000
# 10    -77.226624  38.874329     837.0   -0.2500
# 11    -87.162903  37.753113     872.0    0.6800
# 12    -77.727905  40.970093     896.0   -0.1027
# 13   -100.445801  39.783875    1032.0    0.0000
# 14   -118.242676  34.053711    1100.0    0.0000
# 15    -93.036804  44.893921    1125.0    0.0000
# 16    -88.314697  36.610474    1218.0    0.4404
# 17    -88.012512  44.512695    1238.0    0.4215
# ...

# %%
tweets2 = tweets.sample(50)

# %%
tweets2
# Out:
#                X          Y  OBJECTID  compound  \
# 4693 -118.242676  34.053711       NaN       NaN
# 340  -100.445801  39.783875   15037.0    0.4926
# 4326  -77.036499  38.895081       NaN       NaN
# 3310  -82.519592  40.068115  120816.0    0.0000
# 2216  -84.176575  42.997925       NaN       NaN
# 3404  -89.433716  40.079712  125556.0    0.0000
# 5531  -81.633301  38.350708  203630.0    0.6705
# 3650  -80.336975  40.855713  140537.0    0.0000
# 331  -100.445801  39.783875   14852.0    0.4767
# 4481 -117.825989  33.685730       NaN       NaN
# 5393  -72.370300  41.737305  197354.0   -0.5859
# 4654  -81.463989  27.756897       NaN       NaN
# 289  -123.094910  44.050476   12473.0    0.0000
# 871   -89.433716  40.079712   36959.0    0.0000
# 89   -102.410706  34.233276    3729.0    0.0000
# 675  -105.992981  34.570923   30171.0    0.0000
# 1362  -96.796875  32.776306   58878.0    0.0000
# 2482  -77.036499  38.895081       NaN       NaN
# ...

# %%
filename = '/Volumes/Untitled/Desktop/grant_work/twitter-code/bayes/bug_testing_v2/by_hashtag/coal_rs.csv'
 
tweets2.to_csv(filename, index=False, encoding='utf-8')

# %%
tweets = pd.read_csv('/Volumes/Untitled/Desktop/grant_work/twitter-code/bayes/bug_testing_v2/by_hashtag/solar.csv')

# %%
tweets2 = tweets.sample(50)

# %%
filename = '/Volumes/Untitled/Desktop/grant_work/twitter-code/bayes/bug_testing_v2/by_hashtag/solar_rs.csv'
 
tweets2.to_csv(filename, index=False, encoding='utf-8')
