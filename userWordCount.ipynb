# %%
import os
import time
import datetime

from collections import Counter
import numpy as np
import pandas as pd
import unicodedata

# %%
df = pd.read_csv('/Volumes/Untitled/Desktop/grant_work/working/twitter-code/user-tweets/user-sentiment-analysis/user_timeline_theCityofSac_SA.csv', error_bad_lines=False, encoding='utf8', engine='python')

# %%
count = Counter(" ".join(df["tweet_without_stopwords"]).split()).most_common(50)
count = pd.DataFrame(count)
count.columns = ['Word', 'Count']
count
# Out:
#                 Word  Count
# 0       TheCityofSac    534
# 1         Sacramento    411
# 2               City    315
# 3        #Sacramento    125
# 4         SacPolice:    113
# 5                 us    111
# 6               Park    110
# 7                new    110
# 8    AngeliqueAshby:    110
# 9       DowntownSac:    101
# 10  Mayor_Steinberg:    101
# 11                We    100
# 12               Sac     96
# 13             today     96
# 14        https://t…     95
# 15               via     89
# 16             water     85
# 17               Day     82
# 18         SacPolice     81
# 19           https:…     78
# 20                 1     75
# 21    NWSSacramento:     73
# 22       SacFirePIO:     72
# 23              city     71
# 24   SacCityUtility:     71
# 25              Join     71
# 26          https:/…     68
# 27               day     68
# 28            https…     65
# 29                pm     63
# 30      LarryCarrD8:     63
# 31     Golden1Center     62
# ...

# %%
df
# Out:
#       contributors  coordinates           created_at  \
# 0              NaN          NaN  2017-09-22 23:15:33
# 1              NaN          NaN  2017-09-22 17:31:35
# 2              NaN          NaN  2017-09-22 17:27:08
# 3              NaN          NaN  2017-09-22 16:24:59
# 4              NaN          NaN  2017-09-22 16:24:53
# 5              NaN          NaN  2017-09-21 23:33:30
# 6              NaN          NaN  2017-09-21 21:49:35
# 7              NaN          NaN  2017-09-21 21:41:36
# 8              NaN          NaN  2017-09-21 19:47:04
# 9              NaN          NaN  2017-09-21 18:09:26
# 10             NaN          NaN  2017-09-21 16:50:23
# 11             NaN          NaN  2017-09-21 16:11:14
# 12             NaN          NaN  2017-09-21 16:11:11
# 13             NaN          NaN  2017-09-21 16:11:04
# 14             NaN          NaN  2017-09-21 15:25:34
# 15             NaN          NaN  2017-09-20 23:13:39
# 16             NaN          NaN  2017-09-20 19:19:05
# ...
